# %%
from plottingRB import *
import glob

# %%
analytics_paths = glob.glob('sales-reports/sales-report-DESIsurvey*.csv')
redbubble_data = read_rb_analytics(analytics_paths)
# Out:
# Found Records through: 2023-09-28 00:00:00

# %%
redbubble_data
# Out:
#    Order Date  Ship Date                                         Work  \
# 0   20 Jan 22  22 Jan 22                           Cosmic Cartography
# 1   20 Jan 22  24 Jan 22                            KP Weather Camera
# 2   17 Jan 22  21 Jan 22                                  Desi Coyote
# 3   17 Jan 22  20 Jan 22                                    DESI Logo
# 4   17 Jan 22  20 Jan 22  Coma Cluster from the Legacy Imaging Survey
# ..        ...        ...                                          ...
# 2   28 Sep 23  29 Sep 23                    Desi Coyote - Canis Major
# 3   28 Sep 23  29 Sep 23                              M31 Focal Plane
# 4    9 Sep 23  11 Sep 23                                   DESI plane
# 5    3 Sep 23   6 Sep 23                                    DESI Logo
# 6    3 Sep 23   6 Sep 23                    Desi Coyote - Canis Major
#
#      Order #              Product Fulfilment Country Destination Country  \
# ...

# %%
# see the total designs ordered
plot_design_hist(redbubble_data, save_path=False)

# %%
# see the designs ordered per order
plot_design_hist(redbubble_data, per_order=True, save_path=False)

# %%
# total products
plot_product_hist(redbubble_data, per_order=True)

# %%
# print some summary info
print_order_summary(redbubble_data)
print_most_common_products(redbubble_data, n=10)
# Out:
# n orders: 116
# n products: 307
# Most common products:
# [('Premium T-ShirtDESI plane', 33), ('MugDESI Logo', 15), ('StickerDESI Logo', 13), ('StickerDesi Coyote - Canis Major', 12), ('PosterCosmic Cartography', 12), ('MugComa Cluster from the Legacy Imaging Survey', 11), ('StickerM31 Focal Plane', 11), ('StickerDESI plane', 10), ('Baseball CapDESI Logo with text', 10), ('Premium T-ShirtDESI Logo', 9)]

# %%
cost_estimates(redbubble_data)
# Out:
# Av. order est.: 53.85904772413795
